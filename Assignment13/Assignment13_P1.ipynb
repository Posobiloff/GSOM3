# %%
import numpy as np
income = np.array([1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000], dtype = int)
income_without_tax = income * 0.7
expenses = np.array([500, 1000, 1000, 2000, 2000, 3000, 3000, 4000, 3000, 2000], dtype = int)
import pandas as pd
d = {
    "Expenses (mln. $)": pd.Series(expenses, ["Jan.", "Feb.", "Mar.", "Apr.", "May", "Jun.", "Jul.", "Aug.", "Sep.", "Oct."]),
    "Income without tax (mln. $)": pd.Series(income_without_tax, ["Jan.", "Feb.", "Mar.", "Apr.", "May", "Jun.", "Jul.", "Aug.", "Sep.", "Oct."])
}
annual_report = pd.DataFrame(d)
annual_report
# Out:
#       Expenses (mln. $)  Income without tax (mln. $)
# Jan.                500                        700.0
# Feb.               1000                       1400.0
# Mar.               1000                       2100.0
# Apr.               2000                       2800.0
# May                2000                       3500.0
# Jun.               3000                       4200.0
# Jul.               3000                       4900.0
# Aug.               4000                       5600.0
# Sep.               3000                       6300.0
# Oct.               2000                       7000.0

# %%
import matplotlib.pyplot as plt
xpoints = ["Jan.", "Feb.", "Mar.", "Apr.", "May", "Jun.", "Jul.", "Aug.", "Sep.", "Oct."]
#bar 1
plt.subplot(1,2,1)
plt.plot(xpoints, income, color = "r")
plt.title("INCOME")

#bar 2
plt.subplot(1,2,2)
plt.plot(xpoints, income_without_tax, color = "b")
plt.title("INCOME WITHOUT TAX")
# Out:
# Text(0.5, 1.0, 'INCOME WITHOUT TAX')

# %%
#bar 3
plt.subplot(1,2,1)
plt.bar(xpoints, income-expenses, color = "m")
plt.title("SAVINGS")
#bar 3
plt.subplot(1,2,2)
plt.bar(xpoints, income_without_tax-expenses, color = "cyan")
plt.title("NET SAVINGS")
# Out:
# Text(0.5, 1.0, 'NET SAVINGS')

# %%
general_savings = sum(income_without_tax-expenses)
savings = income_without_tax-expenses
shares = savings/general_savings
plt.pie(shares, labels = xpoints, autopct='%1.1f%%', colors=['r', 'g', 'b', 'c', 'm', 'y', 'maroon', 'w','rosybrown', 'gray'] )
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3fa2df5930>,
#   <matplotlib.patches.Wedge at 0x7f3fa2df5f60>,
#   <matplotlib.patches.Wedge at 0x7f3fa2df65f0>,
#   <matplotlib.patches.Wedge at 0x7f3fa2df6c80>,
#   <matplotlib.patches.Wedge at 0x7f3fa2df7310>,
#   <matplotlib.patches.Wedge at 0x7f3fa2df79a0>,
#   <matplotlib.patches.Wedge at 0x7f3fa2c18070>,
#   <matplotlib.patches.Wedge at 0x7f3fa2c18730>,
#   <matplotlib.patches.Wedge at 0x7f3fa2c18dc0>,
#   <matplotlib.patches.Wedge at 0x7f3fa2c19450>],
#  [Text(1.0992487661279438, 0.04064665012265536, 'Jan.'),
#   Text(1.0880007687397593, 0.1620318710059625, 'Feb.'),
#   Text(1.0021249070822311, 0.45359196488190795, 'Mar.'),
#   Text(0.7849711468821085, 0.7705973647519094, 'Apr.'),
#   Text(0.3973657922029253, 1.0257194680744546, 'May'),
#   Text(-0.1418991999862417, 1.0908091570221001, 'Jun.'),
#   Text(-0.7105209269503981, 0.8397380617582766, 'Jul.'),
#   Text(-1.0730631835497815, 0.24194091036864454, 'Aug.'),
#   Text(-0.8527243085191673, -0.6948821868925036, 'Sep.'),
#   Text(0.6628982254133028, -0.8778188553134948, 'Oct.')],
#  [Text(0.5995902360697875, 0.022170900066902918, '1.2%'),
#   Text(0.5934549647671413, 0.08838102054870682, '2.4%'),
#   Text(0.5466135856812169, 0.2474137990264952, '6.5%'),
#   Text(0.42816608011751367, 0.4203258353192233, '4.7%'),
#   Text(0.21674497756523195, 0.5594833462224297, '8.8%'),
#   Text(-0.0773995636288591, 0.5949868129211455, '7.1%'),
#   Text(-0.3875568692456717, 0.45803894277724166, '11.2%'),
#   Text(-0.5853071910271535, 0.13196776929198792, '9.4%'),
#   Text(-0.4651223501013639, -0.379026647395911, '19.4%'),
#   Text(0.36158085022543784, -0.4788102847164516, '29.4%')])

# %%
import statistics as st
print(f"The average income for the first quarter is {st.mean([income_without_tax[0], income_without_tax[1], income_without_tax[2]])} $")
print(f"The average income for the second quarter is {st.mean([income_without_tax[3], income_without_tax[4], income_without_tax[5]])} $")
print(f"The average income for the third quarter is {st.mean([income_without_tax[6], income_without_tax[7], income_without_tax[8]])} $")
# Out:
# The average income for the first quarter is 1400.0 $
# The average income for the second quarter is 3500.0 $
# The average income for the third quarter is 5600.0 $
